# %% [markdown]
# # **Processamento de Linguagem Natural [2023.Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **ATIVIDADE PRÁTICA 04 [Uso da API da OpenAI com técnicas de PLN]**

# %% [markdown]
# A **ATIVIDADE PRÁTICA 04** deve ser feita utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook, armazenado no Google Drive, além do link de um repositório no GitHub e os principais resultados da atividade, devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/GzwCq3R7ExtE9g9a8
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia 20/11 (segunda-feira) APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina de PLN.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# André Barros Balchiumas 11201920328
#
# **Integrante 02:**
#
# Guilherme Goncalves Braz 11201920453

# %% [markdown]
# ### **LIVRO**
# ---

# %% [markdown]
# `Processamento de Linguagem Natural - Conceitos, Técnicas e Aplicações em Português.`
#
# >
#
# Disponível gratuitamente em:
#
#   > https://brasileiraspln.com/livro-pln/1a-edicao/.
#
#
# **POR FAVOR, PREENCHER OS CAPITULOS SELECIONADOS PARA A SUA EQUIPE:**
#
# `Primeiro capítulo: 6`
#
# `Segundo capítulo: 19`

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso da **API da OpenAI** aplicando, no mínimo, 3 técnicas de PLN. As técnicas devem ser aplicadas nos 2 (DOIS) capítulos do livro **Processamento de Linguagem Natural - Conceitos, Técnicas e Aplicações em Português**.
#
# >
#
# **RESTRIÇÃO**: É obrigatório usar o *endpoint* "*`Chat Completions`*".
#
# >
#
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   **Similaridade de Textos**
# *   **Reconhecimento de Entidades Nomeadas**
# *   **Sistemas de Perguntas e Respostas**
#
# >
#
# Os capítulos devem ser os mesmos selecionados na **ATIVIDADE PRÁTICA 02**. Para consultar os capítulos, considere a seguinte planilha:
#
# >
#
# > https://docs.google.com/spreadsheets/d/1ZutzQ3v1OJgsgzCvCwxXlRIQ3ChXNlHNvB63JQvYsbo/edit?usp=sharing
#
# >
# >
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC. Não é permitido alterar os capítulos já selecionados.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação as técnicas usadas e a criatividade envolvida na aplicação das mesmas.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# # Imports necessários

# %%
import os
import re
import random
from pathlib import Path

# bibliotecas third-party
from requests import get  # pip install requests
from bs4 import BeautifulSoup as bs  # pip install beautifulsoup4
from openai import OpenAI # pip install openai
from dotenv import load_dotenv  # pip install python-dotenv

# %% [markdown]
# ## Extração do texto capítulos 6 e 19 do livro
#
# Como os capítulos do livro possuem MUITOS caractéres, estamos selecionando somente parágrafos com mais de 5 palavras.
#
# Desses parágrafos selecionados, quatro estão sendo selecionados aleatoriamente para fins de uso com a API do OpenAI.
#
# Isso se deve ao fato de haver um limite na quantidade mensal de tokens que podem ser utilziados na API.

# %%
def extract_text_from_html(url : str) -> list[str]:
    content = []
    request = get(url)
    if request.status_code == 200:
        soup = bs(request.content.decode('utf-8'), features="html.parser")
        paragraphs = soup.find_all("p")
        for paragraph in paragraphs:
            text = paragraph.get_text()
            if len(text.split()) > 5: # verifica se o parágrafo tem mais de 5 palavras
                content.append(text)
    return content

# %%
def get_random_paragraphs(content: list[str]) -> list[str]:
    if len(content) >= 4:
        return random.sample(content, 4)
    else:
        return None

# %%
cap6_raw = extract_text_from_html("https://brasileiraspln.com/livro-pln/1a-edicao/parte4/cap6/cap6.html")
cap6_rand = get_random_paragraphs(cap6_raw)

# %%
cap19_raw = extract_text_from_html("https://brasileiraspln.com/livro-pln/1a-edicao/parte8/cap19/cap19.html")
cap19_rand = get_random_paragraphs(cap19_raw)

# %% [markdown]
# ## Localizando o arquivo .env dentro do repo

# %%
def find_dotenv() -> str:
    for root, dirs, files in os.walk(str(Path(os.getcwd()).parents[0])):
        if '.env' in files:
            dotenv_path = os.path.join(root, '.env')
            load_dotenv(dotenv_path)
            return dotenv_path
    return None

# %% [markdown]
# # Definição de técnicas de PLN com o Chat Completions (API v1.3.3)

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
def chat_with_api(system_role : str, prompt: str) -> str:
    try:
        response = client.chat.completions.create(
            messages = [
                {"role": "system", "content": system_role},
                {"role": "user", "content": prompt},
            ],
            model="gpt-3.5-turbo"
        )
        response_text = response.choices[0].message.content
        return response_text
    except Exception as e:
        print(f"Erro ao comunicar com a API: {e}")
        return None
    
def print_response(paragraph_list : list[str], function):
   for paragraph in paragraph_list:
        print('-' * 150)
        print(f'Parágrafo: {paragraph}')
        print(f'Reposta da API: {function(paragraph)}')

# %% [markdown]
# # Das técnicas listadas, algumas serão utilizadas com os parágrafos selecionados aleatoriamente.

# %% [markdown]
# ## Técnica 1: Correção Gramatical

# %%
def correcao_gramatical(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente de correção textual que vai me ajudar a achar erros gramaticais no texto apresentado",
                         prompt=prompt)

# %%
print_response(cap6_rand, correcao_gramatical)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: A raiz, assim como acontece na representação por diagrama arbóreo, também é representada em uma das linhas, como se fosse “dependente” de um núcleo fictício, chamado ROOT, representado por letras maiúsculas, em uma relação chamada root representada por letras minúsculas. O elemento ROOT representa o elemento vazio.
# Reposta da API: A raiz, assim como acontece na representação por diagrama arbóreo, também é representada em uma das linhas, como se fosse "dependente" de um núcleo fictício, chamado ROOT, representado por letras maiúsculas, em uma relação chamada root representada por letras minúsculas. O elemento ROOT representa o elemento vazio.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Retomando o Exemplo 6.3 temos, então, os seguintes sintagmas: “a menina”, que é um sintagma nominal, pois o seu constituinte principal é o substantivo “menina”; e “postou uma foto”, que é um sintagma verbal, pois seu constituinte principal é o verbo “postou”; dentro do sintagma verbal temos ainda um outro sintagma, “uma foto”, que é considerado um sintagma nominal, pois seu constituinte principal é o substantivo “foto”. É importante notar, portanto, que pode haver um ou mais sintagmas dentro de um outro sintagma. Esse constituinte principal que dita qual é o tipo de sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical, ou seja, do sintagma.
# Reposta da API: Retomando o Exemplo 6.3, temos, então, os seguintes sintagmas: "a menina", que é um sintagma nominal, pois o seu constituinte principal é o substantivo "menina"; e "postou uma foto", que é um sintagma verbal, pois o seu constituinte principal é o verbo "postou". Dentro do sintagma verbal, temos ainda outro sintagma, "uma foto", que é considerado um sintagma nominal, pois o seu constituinte principal é o substantivo "foto". É importante notar, portanto, que pode haver um ou mais sintagmas dentro de um outro sintagma. Esse constituinte principal que dita qual é o tipo de sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical, ou seja, do sintagma.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Vale ressaltar que estes termos também são usados em inglês: “parent”, “child”, “grandparent”, “grandchild” e “sibling”.↩︎
# Reposta da API: Não foram encontrados erros gramaticais no texto apresentado.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Seguindo essa ideia de universalizar as representações de dependência para várias línguas, Google também criou seu próprio conjunto de etiquetas, baseando-se na análise de erros que foi feita para aquela shared task do CoNLL-X.
# Reposta da API: Seguindo essa ideia de universalizar as representações de dependência para várias línguas, o Google também criou seu próprio conjunto de etiquetas, baseando-se na análise de erros que foi feita para aquela shared task do CoNLL-X.

# %%
print_response(cap19_rand, correcao_gramatical)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Cada uma dessas etapas pode ser vista como uma aplicação independente no PLN. Por exemplo, existem várias ferramentas de auxílio à escrita, bem como corretores ortográficos e gramaticais, que executam exclusivamente a tarefa de identificação de desvios no texto; e isso constitui uma aplicação em si. Da mesma forma, a tarefa de dar um feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem geração de linguagem natural (ou Natural Language Generation).
# Reposta da API: Cada uma dessas etapas pode ser vista como uma aplicação independente no PLN. Por exemplo, existem várias ferramentas de auxílio à escrita, bem como corretores ortográficos e gramaticais, que executam exclusivamente a tarefa de identificação de desvios no texto. Isso constitui uma aplicação em si. Da mesma forma, a tarefa de dar um feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem geração de linguagem natural (ou Natural Language Generation).
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação como Coerência e Coesão. No entanto, critérios como Tema são melhor avaliados por atributos dependentes de conteúdo, como exemplo as matrizes de termos, descritas no Capítulo 14, e métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre tema e redação em Amorim; Veloso (2017). Em Louis; Higgins (2010) e Persing; Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# Reposta da API: Trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação, como coerência e coesão. No entanto, critérios como tema são melhor avaliados por atributos dependentes de conteúdo, como as matrizes de termos descritas no Capítulo 14, e métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre tema e redação em Amorim e Veloso (2017). Em Louis e Higgins (2010) e Persing e Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Para o português, existem recursos disponíveis, tais como o CoGroo15 e o LanguageTool16, que são repositórios contendo regras gramaticais para a língua portuguesa. Esses recursos têm versões livres, gratuitas e de código-aberto, com extensão para navegadores web e também acopláveis a editores de texto.
# Reposta da API: O texto está correto em relação à gramática. No entanto, seria melhor adicionar os links dos recursos mencionados para facilitar a pesquisa dos leitores. Ficaria assim:
#
# Para o português, existem recursos disponíveis, tais como o CoGroo15 e o LanguageTool16, que são repositórios contendo regras gramaticais para a língua portuguesa. Esses recursos têm versões livres, gratuitas e de código-aberto, com extensão para navegadores web e também acopláveis a editores de texto. [Link 1] [Link 2]
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Manual do ingresso (https://www.comvest.unicamp.br/wp-content/uploads/2023/02/Manual_do_Ingresso_2023_Atualizado.pdf) e grade de redação (https://www.comvest.unicamp.br/vestibular-2023/grade-da-redacao/) do vestibular 2023 da Unicamp.↩︎
# Reposta da API: O texto apresentado não possui erros gramaticais. No entanto, é importante mencionar que os termos "Manual do Ingresso" e "Grade de Redação" devem ser escritos com inicial maiúscula, já que se referem a títulos. Então, o correto seria "Manual do Ingresso" e "Grade de Redação" do vestibular 2023 da Unicamp.

# %% [markdown]
# ## Técnica 2: Classificação de Textos

# %%
def classificacao_textos(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente de classificação textual que vai me ajudar a classificar o texto apresentado",
                         prompt=prompt)

# %%
print_response(cap6_rand, classificacao_textos)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: A raiz, assim como acontece na representação por diagrama arbóreo, também é representada em uma das linhas, como se fosse “dependente” de um núcleo fictício, chamado ROOT, representado por letras maiúsculas, em uma relação chamada root representada por letras minúsculas. O elemento ROOT representa o elemento vazio.
# Reposta da API: O texto apresentado fala sobre a representação da raiz em uma estrutura de diagrama arbóreo. Nessa estrutura, a raiz é representada como dependente de um núcleo fictício chamado ROOT, que é representado por letras maiúsculas. Essa relação é chamada de root e é representada por letras minúsculas. O elemento ROOT representa o elemento vazio. Considerando esse contexto, o texto se enquadra na área de Linguística ou Processamento de Linguagem Natural.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Retomando o Exemplo 6.3 temos, então, os seguintes sintagmas: “a menina”, que é um sintagma nominal, pois o seu constituinte principal é o substantivo “menina”; e “postou uma foto”, que é um sintagma verbal, pois seu constituinte principal é o verbo “postou”; dentro do sintagma verbal temos ainda um outro sintagma, “uma foto”, que é considerado um sintagma nominal, pois seu constituinte principal é o substantivo “foto”. É importante notar, portanto, que pode haver um ou mais sintagmas dentro de um outro sintagma. Esse constituinte principal que dita qual é o tipo de sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical, ou seja, do sintagma.
# Reposta da API: O texto apresentado descreve os diferentes tipos de sintagmas presentes em um exemplo específico, que é analisado em relação à sua estrutura gramatical. O autor menciona dois tipos de sintagmas identificados no exemplo: o sintagma nominal, com o constituinte principal "a menina"; e o sintagma verbal, com o constituinte principal "postou uma foto". Além disso, é destacado que dentro do sintagma verbal há outro sintagma, o sintagma nominal "uma foto". É ressaltado que o constituinte principal de cada sintagma é chamado de núcleo, pois ele define o tipo de sintagma.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Vale ressaltar que estes termos também são usados em inglês: “parent”, “child”, “grandparent”, “grandchild” e “sibling”.↩︎
# Reposta da API: Este texto é uma informação.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Seguindo essa ideia de universalizar as representações de dependência para várias línguas, Google também criou seu próprio conjunto de etiquetas, baseando-se na análise de erros que foi feita para aquela shared task do CoNLL-X.
# Reposta da API: O texto apresentado se enquadra na categoria de Tecnologia/Informática, pois menciona a criação pelo Google de um conjunto de etiquetas para a análise de erros em várias línguas.

# %%
print_response(cap19_rand, classificacao_textos)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Cada uma dessas etapas pode ser vista como uma aplicação independente no PLN. Por exemplo, existem várias ferramentas de auxílio à escrita, bem como corretores ortográficos e gramaticais, que executam exclusivamente a tarefa de identificação de desvios no texto; e isso constitui uma aplicação em si. Da mesma forma, a tarefa de dar um feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem geração de linguagem natural (ou Natural Language Generation).
# Reposta da API: O texto apresentado descreve diferentes etapas do processamento de linguagem natural (PLN) e destaca a importância de cada uma delas. Além disso, menciona que cada uma dessas etapas pode ser vista como uma aplicação independente no PLN.
#
# Portanto, considerando a natureza do texto, ele pode ser classificado como um texto informativo que discute as diferentes aplicações do PLN e sua relevância em cada etapa do processamento de linguagem natural.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação como Coerência e Coesão. No entanto, critérios como Tema são melhor avaliados por atributos dependentes de conteúdo, como exemplo as matrizes de termos, descritas no Capítulo 14, e métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre tema e redação em Amorim; Veloso (2017). Em Louis; Higgins (2010) e Persing; Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# Reposta da API: O texto apresentado menciona que trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação como Coerência e Coesão. No entanto, para avaliar critérios como o Tema, é mais adequado utilizar atributos dependentes de conteúdo, como as matrizes de termos descritas no Capítulo 14 e as métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre o tema e a redação em Amorim; Veloso (2017).
#
# Além disso, o texto menciona que em Louis; Higgins (2010) e Persing; Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Para o português, existem recursos disponíveis, tais como o CoGroo15 e o LanguageTool16, que são repositórios contendo regras gramaticais para a língua portuguesa. Esses recursos têm versões livres, gratuitas e de código-aberto, com extensão para navegadores web e também acopláveis a editores de texto.
# Reposta da API: O texto apresentado descreve recursos disponíveis para a língua portuguesa, especificamente o CoGroo e o LanguageTool. Esses recursos são repositórios de regras gramaticais que podem ser usados ​​em navegadores da web e editores de texto.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Manual do ingresso (https://www.comvest.unicamp.br/wp-content/uploads/2023/02/Manual_do_Ingresso_2023_Atualizado.pdf) e grade de redação (https://www.comvest.unicamp.br/vestibular-2023/grade-da-redacao/) do vestibular 2023 da Unicamp.↩︎
# Reposta da API: O texto apresentado consiste em dois links: o manual do ingresso e a grade de redação do vestibular 2023 da Unicamp. O manual do ingresso fornece informações sobre o processo seletivo, as modalidades de ingresso, cronograma, documentação necessária, entre outros detalhes relevantes para os candidatos. Já a grade de redação descreve os critérios de avaliação da prova de redação do vestibular, incluindo os aspectos que são observados na correção e a pontuação atribuída a cada um deles.

# %% [markdown]
# ## Técnica 3: Análise de Sentimentos

# %%
def analise_sentimentos(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente que faz análises sentimentais com base no texto apresentado",
                         prompt=prompt)

# %% [markdown]
# ## Técnica 4: Detecção de Emoções

# %%
def deteccao_emocoes(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente de detecção de emoções com base no texto apresentado",
                         prompt=prompt)

# %% [markdown]
# ## Técnica 5: Extração de Palavras-chave

# %%
def extraca_palavras_chave(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente textual que vai me ajudar a extrair palavras-chave do texto apresentado",
                         prompt=prompt)

# %%
print_response(cap6_rand, extraca_palavras_chave)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: A raiz, assim como acontece na representação por diagrama arbóreo, também é representada em uma das linhas, como se fosse “dependente” de um núcleo fictício, chamado ROOT, representado por letras maiúsculas, em uma relação chamada root representada por letras minúsculas. O elemento ROOT representa o elemento vazio.
# Reposta da API: palavras-chave:
# - raiz
# - representação
# - diagrama arbóreo
# - linhas
# - dependente
# - núcleo fictício
# - ROOT
# - letras maiúsculas
# - relação
# - letras minúsculas
# - elemento vazio
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Retomando o Exemplo 6.3 temos, então, os seguintes sintagmas: “a menina”, que é um sintagma nominal, pois o seu constituinte principal é o substantivo “menina”; e “postou uma foto”, que é um sintagma verbal, pois seu constituinte principal é o verbo “postou”; dentro do sintagma verbal temos ainda um outro sintagma, “uma foto”, que é considerado um sintagma nominal, pois seu constituinte principal é o substantivo “foto”. É importante notar, portanto, que pode haver um ou mais sintagmas dentro de um outro sintagma. Esse constituinte principal que dita qual é o tipo de sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical, ou seja, do sintagma.
# Reposta da API: palavras-chave: Exemplo 6.3, sintagmas, menina, nominal, substantivo, postou uma foto, verbal, verbo, uma foto, estrutura gramatical, núcleo.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Vale ressaltar que estes termos também são usados em inglês: “parent”, “child”, “grandparent”, “grandchild” e “sibling”.↩︎
# Reposta da API: palavras-chave: termos, usados, inglês, parent, child, grandparent, grandchild, sibling
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Seguindo essa ideia de universalizar as representações de dependência para várias línguas, Google também criou seu próprio conjunto de etiquetas, baseando-se na análise de erros que foi feita para aquela shared task do CoNLL-X.
# Reposta da API: palavras-chave: universalizar, representações de dependência, várias línguas, Google, conjunto, etiquetas, análise de erros, shared task, CoNLL-X.

# %%
print_response(cap19_rand, extraca_palavras_chave)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Cada uma dessas etapas pode ser vista como uma aplicação independente no PLN. Por exemplo, existem várias ferramentas de auxílio à escrita, bem como corretores ortográficos e gramaticais, que executam exclusivamente a tarefa de identificação de desvios no texto; e isso constitui uma aplicação em si. Da mesma forma, a tarefa de dar um feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem geração de linguagem natural (ou Natural Language Generation).
# Reposta da API: etapas, aplicação, PLN, ferramentas, auxílio à escrita, corretores ortográficos e gramaticais, identificação de desvios, texto, feedback, sugestões, aluno, geração de linguagem natural, Natural Language Generation
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação como Coerência e Coesão. No entanto, critérios como Tema são melhor avaliados por atributos dependentes de conteúdo, como exemplo as matrizes de termos, descritas no Capítulo 14, e métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre tema e redação em Amorim; Veloso (2017). Em Louis; Higgins (2010) e Persing; Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# Reposta da API: palavras-chave: métricas independentes de conteúdo, critérios de avaliação, Coerência, Coesão, critérios, Tema, atributos dependentes de conteúdo, matrizes de termos, similaridade de cosseno, redação, Amorim; Veloso (2017), Louis; Higgins (2010), Persing; Ng (2014), recursos linguísticos pré-definidos, experimentos.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Para o português, existem recursos disponíveis, tais como o CoGroo15 e o LanguageTool16, que são repositórios contendo regras gramaticais para a língua portuguesa. Esses recursos têm versões livres, gratuitas e de código-aberto, com extensão para navegadores web e também acopláveis a editores de texto.
# Reposta da API: palavras-chave: português, recursos, CoGroo15, LanguageTool16, repositórios, regras gramaticais, língua portuguesa, versões livres, gratuitas, código-aberto, extensão, navegadores web, editores de texto.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Manual do ingresso (https://www.comvest.unicamp.br/wp-content/uploads/2023/02/Manual_do_Ingresso_2023_Atualizado.pdf) e grade de redação (https://www.comvest.unicamp.br/vestibular-2023/grade-da-redacao/) do vestibular 2023 da Unicamp.↩︎
# Reposta da API: Palavras-chave do texto sobre o vestibular 2023 da Unicamp:
# - Manual do Ingresso
# - Unicamp
# - Vestibular 2023
# - Comvest
# - Grade de Redação
# - Provas de ingresso
# - Documento atualizado
# - Manual online
# - Processo seletivo
# - Inscrições
# - Calendário do vestibular
# - Edital
# - Prazos
# - Orientações
# - Provas específicas
# - Áreas do conhecimento
# - Redação
# - Critérios de avaliação
# - Temas
# - Resultados
# - Matrícula
# - Análise socioeconômica
# - Políticas de inclusão
# - Cotas
# - Pessoas com deficiência
# - Sistema de ingresso
# - Notas mínimas
# - Classificação dos candidatos
# - Vagas
# - Convocação
# - Segunda fase
# - Composição das provas
# - Escolha de cursos
# - Avaliação das provas
# - Acesso ao Manual do Ingresso 2023
# - Informações adicionais

# %% [markdown]
# ## Técnica 6: Tradução de Textos

# %%
def traducao_textos(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente textual que vai me ajudar a traduzir textos do inglês para o português, somente no caso em que o texto possua palavras em inglês",
                         prompt=prompt)

# %% [markdown]
# ## Técnica 7: Sumarização de Textos

# %%
def sumarizacao_textos(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente de sumarização textual que vai me ajudar a sumarizar o texto apresentado",
                         prompt=prompt)

# %%
print_response(cap6_rand, sumarizacao_textos)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: A raiz, assim como acontece na representação por diagrama arbóreo, também é representada em uma das linhas, como se fosse “dependente” de um núcleo fictício, chamado ROOT, representado por letras maiúsculas, em uma relação chamada root representada por letras minúsculas. O elemento ROOT representa o elemento vazio.
# Reposta da API: A raiz é representada no diagrama arbóreo como "dependente" de um núcleo fictício chamado ROOT. Isso é indicado por letras maiúsculas na estrutura da árvore. A relação é chamada de root e representa o elemento vazio.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Retomando o Exemplo 6.3 temos, então, os seguintes sintagmas: “a menina”, que é um sintagma nominal, pois o seu constituinte principal é o substantivo “menina”; e “postou uma foto”, que é um sintagma verbal, pois seu constituinte principal é o verbo “postou”; dentro do sintagma verbal temos ainda um outro sintagma, “uma foto”, que é considerado um sintagma nominal, pois seu constituinte principal é o substantivo “foto”. É importante notar, portanto, que pode haver um ou mais sintagmas dentro de um outro sintagma. Esse constituinte principal que dita qual é o tipo de sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical, ou seja, do sintagma.
# Reposta da API: O texto apresenta uma análise dos sintagmas presentes no Exemplo 6.3. São identificados dois sintagmas principais: "a menina", que é um sintagma nominal, e "postou uma foto", que é um sintagma verbal. Além disso, é destacado que dentro do sintagma verbal existe outro sintagma nominal, "uma foto". É ressaltado também que o constituinte principal de um sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Vale ressaltar que estes termos também são usados em inglês: “parent”, “child”, “grandparent”, “grandchild” e “sibling”.↩︎
# Reposta da API: Os termos "parent", "child", "grandparent", "grandchild" e "sibling" também são utilizados em inglês.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Seguindo essa ideia de universalizar as representações de dependência para várias línguas, Google também criou seu próprio conjunto de etiquetas, baseando-se na análise de erros que foi feita para aquela shared task do CoNLL-X.
# Reposta da API: A Google desenvolveu seu próprio conjunto de etiquetas de dependência com o objetivo de criar representações universais para várias línguas. Essas etiquetas foram criadas a partir de uma análise de erros realizada durante a shared task do CoNLL-X.

# %%
print_response(cap19_rand, sumarizacao_textos)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Cada uma dessas etapas pode ser vista como uma aplicação independente no PLN. Por exemplo, existem várias ferramentas de auxílio à escrita, bem como corretores ortográficos e gramaticais, que executam exclusivamente a tarefa de identificação de desvios no texto; e isso constitui uma aplicação em si. Da mesma forma, a tarefa de dar um feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem geração de linguagem natural (ou Natural Language Generation).
# Reposta da API: O texto fala sobre como cada etapa do Processamento de Linguagem Natural (PLN) pode ser vista como uma aplicação independente. Por exemplo, existem ferramentas de auxílio à escrita, corretores ortográficos e gramaticais que identificam erros no texto, o que constitui uma aplicação em si. Da mesma forma, a tarefa de dar feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem a geração de linguagem natural.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação como Coerência e Coesão. No entanto, critérios como Tema são melhor avaliados por atributos dependentes de conteúdo, como exemplo as matrizes de termos, descritas no Capítulo 14, e métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre tema e redação em Amorim; Veloso (2017). Em Louis; Higgins (2010) e Persing; Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# Reposta da API: Trabalhos utilizando métricas independentes de conteúdo podem medir critérios como Coerência e Coesão. Por outro lado, critérios como Tema são melhor avaliados por métricas dependentes de conteúdo, como matrizes de termos e a similaridade de cosseno. Essas métricas são calculadas a partir de recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Para o português, existem recursos disponíveis, tais como o CoGroo15 e o LanguageTool16, que são repositórios contendo regras gramaticais para a língua portuguesa. Esses recursos têm versões livres, gratuitas e de código-aberto, com extensão para navegadores web e também acopláveis a editores de texto.
# Reposta da API: Existem recursos disponíveis para o português, como o CoGroo e o LanguageTool. Eles são repositórios de regras gramaticais para o idioma, com versões livres, gratuitas e de código-aberto. Esses recursos podem ser usados como extensões em navegadores web e também acoplados a editores de texto.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Manual do ingresso (https://www.comvest.unicamp.br/wp-content/uploads/2023/02/Manual_do_Ingresso_2023_Atualizado.pdf) e grade de redação (https://www.comvest.unicamp.br/vestibular-2023/grade-da-redacao/) do vestibular 2023 da Unicamp.↩︎
# Reposta da API: O texto apresentado consiste no manual do ingresso e na grade de redação do vestibular 2023 da Unicamp. O manual do ingresso é um documento que contém informações importantes para os candidatos que desejam ingressar na universidade, tais como datas, etapas do processo seletivo e documentação necessária. Já a grade de redação apresenta os critérios de avaliação e pontuação utilizados na correção das redações dos candidatos. Ambos os documentos são disponibilizados pela Comissão Permanente para os Vestibulares (Comvest) da Unicamp e são essenciais para os candidatos se prepararem adequadamente para o vestibular.

# %% [markdown]
# ## Técnica 8: Similaridade de Textos

# %%
def similaridade_textos(prompt1 : str, prompt2 : str) -> str:
    return chat_with_api(system_role="Você é um um assistente textual que vai me ajudar a encontrar similaridades nos textos apresentados",
                         prompt=f'Texto 1: {prompt1}; Texto 2: {prompt2}')

# %% [markdown]
# ## Técnica 9: Reconhecimento de Entidades Nomeadas

# %%
def recon_entidades_nomeadas(prompt : str) -> str:
    return chat_with_api(system_role="Você é um um assistente textual que vai me ajudar a reconhecer/encontar entidades nomeadas no texto apresentado",
                         prompt=prompt)

# %%
print_response(cap6_rand, recon_entidades_nomeadas)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: A raiz, assim como acontece na representação por diagrama arbóreo, também é representada em uma das linhas, como se fosse “dependente” de um núcleo fictício, chamado ROOT, representado por letras maiúsculas, em uma relação chamada root representada por letras minúsculas. O elemento ROOT representa o elemento vazio.
# Reposta da API: No texto apresentado, as seguintes entidades nomeadas foram identificadas:
#
# 1. Diagrama arbóreo
# 2. ROOT (núcleo fictício)
#
# Entidades nomeadas são palavras ou grupos de palavras que se referem a um nome próprio, como pessoas, lugares, organizações, entre outros.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Retomando o Exemplo 6.3 temos, então, os seguintes sintagmas: “a menina”, que é um sintagma nominal, pois o seu constituinte principal é o substantivo “menina”; e “postou uma foto”, que é um sintagma verbal, pois seu constituinte principal é o verbo “postou”; dentro do sintagma verbal temos ainda um outro sintagma, “uma foto”, que é considerado um sintagma nominal, pois seu constituinte principal é o substantivo “foto”. É importante notar, portanto, que pode haver um ou mais sintagmas dentro de um outro sintagma. Esse constituinte principal que dita qual é o tipo de sintagma é chamado de núcleo, pois ele é o núcleo da estrutura gramatical, ou seja, do sintagma.
# Reposta da API: No texto apresentado, algumas entidades nomeadas identificadas são:
#
# 1. Exemplo 6.3
# 2. menina
# 3. postou uma foto
# 4. foto
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Vale ressaltar que estes termos também são usados em inglês: “parent”, “child”, “grandparent”, “grandchild” e “sibling”.↩︎
# Reposta da API: No texto apresentado, as entidades nomeadas são:
#
# - "parent"
# - "child"
# - "grandparent"
# - "grandchild"
# - "sibling"
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Seguindo essa ideia de universalizar as representações de dependência para várias línguas, Google também criou seu próprio conjunto de etiquetas, baseando-se na análise de erros que foi feita para aquela shared task do CoNLL-X.
# Reposta da API: No texto apresentado, as entidades nomeadas identificadas são:
#
# - Google (organização)
# - CoNLL-X (evento/projeto)

# %%
print_response(cap19_rand, recon_entidades_nomeadas)
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Cada uma dessas etapas pode ser vista como uma aplicação independente no PLN. Por exemplo, existem várias ferramentas de auxílio à escrita, bem como corretores ortográficos e gramaticais, que executam exclusivamente a tarefa de identificação de desvios no texto; e isso constitui uma aplicação em si. Da mesma forma, a tarefa de dar um feedback com sugestões para o aluno é semelhante a outras aplicações de PLN que envolvem geração de linguagem natural (ou Natural Language Generation).
# Reposta da API: No texto apresentado, as seguintes entidades nomeadas foram identificadas:
#
# - PLN (Processamento de Linguagem Natural)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Trabalhos que utilizam métricas independentes de conteúdo são capazes de representar critérios de avaliação como Coerência e Coesão. No entanto, critérios como Tema são melhor avaliados por atributos dependentes de conteúdo, como exemplo as matrizes de termos, descritas no Capítulo 14, e métricas calculadas a partir dessas matrizes, como a similaridade de cosseno utilizada entre tema e redação em Amorim; Veloso (2017). Em Louis; Higgins (2010) e Persing; Ng (2014), são propostos cálculos de atributos dependentes de conteúdo com base em recursos linguísticos pré-definidos e associados aos temas relacionados às redações utilizadas nos experimentos.
# Reposta da API: No texto apresentado, há algumas entidades nomeadas que podem ser identificadas:
#
# - Coerência
# - Coesão
# - Tema
# - Matrizes de termos
# - Capítulo 14
# - Similaridade de cosseno
# - Amorim; Veloso (2017)
# - Louis; Higgins (2010)
# - Persing; Ng (2014)
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Para o português, existem recursos disponíveis, tais como o CoGroo15 e o LanguageTool16, que são repositórios contendo regras gramaticais para a língua portuguesa. Esses recursos têm versões livres, gratuitas e de código-aberto, com extensão para navegadores web e também acopláveis a editores de texto.
# Reposta da API: No texto apresentado, foram mencionadas duas entidades nomeadas: "CoGroo15" e "LanguageTool16". Essas entidades parecem ser ferramentas ou recursos relacionados à verificação gramatical e correção de textos em português.
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Parágrafo: Manual do ingresso (https://www.comvest.unicamp.br/wp-content/uploads/2023/02/Manual_do_Ingresso_2023_Atualizado.pdf) e grade de redação (https://www.comvest.unicamp.br/vestibular-2023/grade-da-redacao/) do vestibular 2023 da Unicamp.↩︎
# Reposta da API: No texto fornecido, é possível identificar as seguintes entidades nomeadas:
#
# 1. Unicamp - Universidade Estadual de Campinas: Instituição de ensino superior mencionada no contexto.
#    - Website: comvest.unicamp.br
#
# 2. Manual do Ingresso 2023: Documento que fornece informações sobre o processo de ingresso na Unicamp no ano de 2023.
#    - URL: https://www.comvest.unicamp.br/wp-content/uploads/2023/02/Manual_do_Ingresso_2023_Atualizado.pdf
#
# 3. Vestibular 2023: Processo seletivo realizado pela Unicamp para ingresso de estudantes no ano de 2023.
#
# 4. Grade da Redação: Informações relacionadas às características e critérios da prova de redação do vestibular 2023 da Unicamp.
#    - URL: https://www.comvest.unicamp.br/vestibular-2023/grade-da-redacao/
